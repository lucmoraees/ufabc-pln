# %% [markdown]
# <a href="https://colab.research.google.com/github/lucmoraees/ufabc-pln/blob/main/2023_Q3_PLN_ATIVIDADE_PRA%CC%81TICA_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Processamento de Linguagem Natural [2023.Q3]**
# Prof. Alexandre Donizeti Alves

# %% [markdown]
# ### **ATIVIDADE PRÁTICA 05 [LangChain + Grandes Modelos de Linguagem + API]**

# %% [markdown]
# A **ATIVIDADE PRÁTICA 05** deve ser feita utilizando o **Google Colab** com uma conta sua vinculada ao Gmail. O link do seu notebook, armazenado no Google Drive, além do link de um repositório no GitHub e os principais resultados da atividade, devem ser enviados usando o seguinte formulário:
#
# > https://forms.gle/C1oUi1FKTZ4W9fNdA
#
#
# **IMPORTANTE**: A submissão deve ser feita até o dia **10/12 (domingo)** APENAS POR UM INTEGRANTE DA EQUIPE, até às 23h59. Por favor, lembre-se de dar permissão de ACESSO IRRESTRITO para o professor da disciplina de PLN.

# %% [markdown]
# ### **EQUIPE**
#
# ---

# %% [markdown]
# **POR FAVOR, PREENCHER OS INTEGRANDES DA SUA EQUIPE:**
#
#
# **Integrante 01:**
#
# `Por favor, informe o seu nome completo e RA:` Felipe Toguchi 11202130303
#
# **Integrante 02:**
#
# `Por favor, informe o seu nome completo e RA:` Lucas Moraes de Carvalho 11202020345
#
# **Integrante 03:**
#
# `Por favor, informe o seu nome completo e RA:` Munir Abrão Dib 11202130880

# %% [markdown]
# ### **GRANDE MODELO DE LINGUAGEM (*Large Language Model - LLM*)**
#
# ---

# %% [markdown]
# Cada equipe deve selecionar um Grande Modelo de Linguagem (*Large Language Model - LMM*). Preferencialmente, usar um modelo gratuito. Cada modelo pode ser escolhido por até 4 equipes.
#
# >
#
# Uma lista de LLMs está disponível em:
#
# > https://integrations.langchain.com/llms
# > https://python.langchain.com/docs/integrations/llms/

# %% [markdown]
# **Modelos da Hugging Face:**
#
# * Mistral Base: modelo promissor.
#
# > https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.1
#
# * Mistral Quantizado: mais leve. Pode ser um pouco mais difícil de configurar, mas deve ocupar menos memória.
#
# > https://huggingface.co/TheBloke/Mistral-7B-Instruct-v0.1-GGUF
#
# * Mistral Lite da Amazon: pode ter desempenho melhor.
#
# > https://huggingface.co/amazon/MistralLite
#
# * Llama 2 7B: modelo da Meta melhorado.
#
# > https://huggingface.co/meta-llama/Llama-2-7b-chat-hf
#
# * Llama 2 7b 32k: contexto maior pelo mesmo tamanho.
#
# > https://huggingface.co/togethercomputer/Llama-2-7B-32K-Instruct
#
# * Galactica: para artigos científicos
#
# > https://huggingface.co/facebook/galactica-6.7b
#
# * Alpaca: alternativo ao Llama
#
# > https://huggingface.co/chavinlo/alpaca-native
#
# > https://huggingface.co/spaces/tloen/alpaca-lora

# %% [markdown]
# **Lista de Modelos Interessantes:**
#
# > https://www.kdnuggets.com/2023/04/8-opensource-alternative-chatgpt-bard.html
#
# * Vicuna:
# > https://huggingface.co/lmsys/vicuna-7b-v1.5-16k
#
# * Openchat kit:
# > https://huggingface.co/togethercomputer/GPT-NeoXT-Chat-Base-20B
#
# * Meta OPT:
# > https://huggingface.co/facebook/opt-1.3b
#
# * Google Flan:
# > https://huggingface.co/google/flan-t5-base

# %% [markdown]
# **APIs:**
#
# * GPT4ALL: tenta ser um chatGPT aberto
# > https://python.langchain.com/docs/integrations/llms/gpt4all
#
# * YandexGPT: da empresa russa que criou um modelo de *Machine Learning* clássico muito bom, o CatBoost.
# > https://python.langchain.com/docs/integrations/llms/yandex
#
# * Anthropic: empresa forte concorrente da OpenAi.
# > https://python.langchain.com/docs/integrations/chat/anthropic
#
# * Gorilla: pipeline para geração de código
#  > https://www.kdnuggets.com/2023/06/meet-gorilla-uc-berkeley-microsoft-apiaugmented-llm-outperforms-gpt4-chatgpt-claude.html

# %% [markdown]
# **IMPORTANTE**: todo esse levantamento e comentários foram feitos pelo aluno  **Bruno Sanches Rodrigues**.

# %% [markdown]
# Por favor, informe os dados do LLM selecionada:
#
# >
#
#
# **LLM**: GPT4ALL
#
# >
#
# **Link para a documentação oficial**: https://api.python.langchain.com/en/latest/llms/langchain.llms.gpt4all.GPT4All.html#
#
# >
#
#
# **Site oficial (GitHub)**: https://github.com/langchain-ai/langchain/blob/master/libs/langchain/langchain/llms/gpt4all.py

# %% [markdown]
# **IMPORTANTE**: não pode ser o modelo da `OpenAI`.

# %% [markdown]
# ### **API**
# ---

# %% [markdown]
# Por favor, informe os dados da API selecionada:
#
# **API**: Wikipedia
#
# **Site oficial**: https://www.mediawiki.org/wiki/API:Main_page/pt
#
# **Link para a documentação oficial**: https://pypi.org/project/wikipedia/

# %% [markdown]
# **IMPORTANTE**: não é necessário usar a mesma **API** da `ATIVIDADE PRÁTICA 03`. Cada **API** pode ser usada por até 4 equipes.

# %% [markdown]
# ### **DESCRIÇÃO**
# ---

# %% [markdown]
# Implementar um `notebook` no `Google Colab` que faça uso do framework **`LangChain`** (obrigatório) e de um **LLM** aplicando, no mínimo, uma técnica de PLN. A técnica pode ser aplicada em qualquer córpus. Também é obrigatório usar uma **API** da `ATIVIDADE PRÁTICA 03`. A **API** pode ser usada tanto para obter os dados quanto para disponibilizar os resultados.
#
# O **LLM** e a **API** selecionados devem ser informados na seguinte planilha:
#
# > https://docs.google.com/spreadsheets/d/1cOL7zVNffqmliuv23zFm1UJjhEXTdp1Zm5EyAJmhiKg/edit?usp=sharing
#
# >
# As seguintes técnicas de PLN podem ser usadas:
#
# *   Correção Gramatical
# *   Classificação de Textos
# *   Análise de Sentimentos
# *   Detecção de Emoções
# *   Extração de Palavras-chave
# *   Tradução de Textos
# *   Sumarização de Textos
# *   Similaridade de Textos
# *   Reconhecimento de Entidades Nomeadas
# *   Sistemas de Perguntas e Respostas
#
# >
#
#
#
#
# **Lista de APIs:**
#
#
# * YouTube
# * LinkedIn
# * Twitter (X)
# * Facebook
# * Instagram
# * Medium
# * Reddit
# * TikTok
# * GitHub
# * Pinterest
# * Telegram
# * Dados financeiros
# * Notícias
# * Mercado de Ações
# * Dados financeiros
# * SMS
# * OpenAlex
# * Whisper (OpenAI)
# * Discord
# * Slack
# * Chuck Norris Jokes
# * Wikipedia
# * Last.fm
# * New York Times
# * Nasdaq Data Link
# * Yahoo! Finance
# * Twilio SendGrid Mail Send
# * Spotify
# * Awesome API
# * Google Books API
# * Mercado Livre API
#
# >
#
# **PLANILHA DA ATIVIDADE PRÁTICA 03:**
#
# > https://docs.google.com/spreadsheets/d/1-Q1szJ3UmoE2_3LtcRQyqid5fPIcnpsR3XAPnoxLj2o/edit?usp=sharing
#
#
# **IMPORTANTE:** É obrigatório usar o e-mail da UFABC.

# %% [markdown]
# ### **CRITÉRIOS DE AVALIAÇÃO**
# ---

# %% [markdown]
# Serão considerados como critérios de avaliação os segunintes pontos:
#
# * Uso do framework **`LangChain`**.
#
# * Escolha e uso de um **LLM**.
#
# * Escolha e uso de uma **API**
#
# * Criatividade no uso do framework **`LangChain`** em conjunto com o **LLM** e a **API**.

# %% [markdown]
# **IMPORTANTE**: todo o código do notebook deve ser executado. Código sem execução não será considerado.

# %% [markdown]
# ### **IMPLEMENTAÇÃO**
# ---

# %% [markdown]
# Primeiro será necessário fazer o download do modelo no site do gpt4all: https://gpt4all.io/index.html

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
GITHUB_ACCESS_TOKEN = ""

# %%
# !pip install langchain && pip install gpt4all && pip install wikipedia-api
# Out:
# Requirement already satisfied: langchain in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (0.0.348)
# Requirement already satisfied: PyYAML>=5.3 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from langchain) (2.0.23)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from langchain) (3.9.1)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from langchain) (0.6.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from langchain) (1.33)
# Requirement already satisfied: langchain-core<0.1,>=0.0.12 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from langchain) (0.0.12)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.63 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from langchain) (0.0.69)
# Requirement already satisfied: numpy<2,>=1 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from langchain) (1.26.2)
# Requirement already satisfied: pydantic<3,>=1 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from langchain) (2.5.2)
# Requirement already satisfied: requests<3,>=2 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from langchain) (8.2.3)
# Requirement already satisfied: attrs>=17.3.0 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.20.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.4)
# Requirement already satisfied: anyio<5,>=3 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from langchain-core<0.1,>=0.0.12->langchain) (4.1.0)
# Requirement already satisfied: packaging<24.0,>=23.2 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from langchain-core<0.1,>=0.0.12->langchain) (23.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from pydantic<3,>=1->langchain) (2.14.5)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from pydantic<3,>=1->langchain) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2023.11.17)
# Requirement already satisfied: sniffio>=1.1 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from anyio<5,>=3->langchain-core<0.1,>=0.0.12->langchain) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from anyio<5,>=3->langchain-core<0.1,>=0.0.12->langchain) (1.2.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (1.0.0)
# Requirement already satisfied: gpt4all in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (2.0.2)
# Requirement already satisfied: requests in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from gpt4all) (2.31.0)
# Requirement already satisfied: tqdm in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from gpt4all) (4.66.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from requests->gpt4all) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from requests->gpt4all) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from requests->gpt4all) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from requests->gpt4all) (2023.11.17)
# Collecting wikipedia-api
#   Downloading Wikipedia_API-0.6.0-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: requests in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from wikipedia-api) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from requests->wikipedia-api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from requests->wikipedia-api) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from requests->wikipedia-api) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/lucmoraes/anaconda3/envs/ufabc/lib/python3.10/site-packages (from requests->wikipedia-api) (2023.11.17)
# Downloading Wikipedia_API-0.6.0-py3-none-any.whl (14 kB)
# Installing collected packages: wikipedia-api
# Successfully installed wikipedia-api-0.6.0

# %% [markdown]
# ### **Sistemas de Perguntas e Respostas**

# %%
from langchain.chains import LLMChain
from langchain.llms import GPT4All
from langchain.prompts import PromptTemplate
import wikipediaapi

# %%
template = """Question: {question}

    Answer: Answer the question in Portuguese using only the content provided below which is written between the ***.
    
    ***
    {context}
    ***
"""

# %%
def build_chain():
    prompt = PromptTemplate(template=template, input_variables=["question", "context"])

    local_path = "models/gpt4all-falcon-q4_0.gguf" # Caminho para o modelo baixado

    llm = GPT4All(model=local_path, backend="gptj", verbose=True)

    llm_chain = LLMChain(prompt=prompt, llm=llm)

    return llm_chain

# %%
def get_wikipedia_page_summary_content(page_name, language='pt'):
    wiki_wiki = wikipediaapi.Wikipedia('Chatbot LLM Summary (lucmoraes27@hotmail.com)', language)
    page_py = wiki_wiki.page(page_name)
    return page_py.summary

# %%
page_name = "Python"
page_summary = get_wikipedia_page_summary_content(page_name)

# Como estamos usando o modelo gpt4all-falcon-q4_0.gguf, o tamanho máximo do contexto é 2048 caractéres
max_context_length = 2048 - len(template)
if len(page_summary) > max_context_length:
    page_summary = page_summary[:max_context_length]

while True:
    llm_chain = build_chain()
    question = input("Question: ")

    if question == "quit":
        break

    print(question)
    answer = llm_chain({"question": question, "context": page_summary})
    print(answer['text'])
    print("\n")
# Out:
# Quem lançou a linguagem python?
# Python é uma linguagem de programação de alto nível, interpretada de script, imperativa, orientada a objetos, funcional, de tipagem dinâmica e forte. Foi lançada por Guido van Rossum em 1991. Atualmente, possui um modelo de desenvolvimento comunitário, aberto e gerenciado pela organizaçã
#
#
# O que você sabe sobre a linguagem python?
#
# Python é uma linguagem de programação que foi desenvolvida para ser fácil de ler e escrever. É uma linguagem multiparadigma, que suporta diversos paradigmas de programação, como o imperativo, o funcional e o procedural. Python é conhecido por sua facilidade de leitura do código e exigir poucas linhas de código se comparado ao mesmo programa em outras linguagens.
#
# Python é utilizada para processamento de textos, dados científicos e criação de páginas dinâmicas para a web. É considerada pelo público como uma linguagem amada, segundo uma pesquisa conduzida pelo site Stack Overflow em 2018. Python está entre as cinco linguagens mais populares, segundo uma pesquisa conduzida pela RedMonk.
#
# A origem do nome Python teve a sua origem no grupo humorístico britânico Monty Python, criador do programa Monty Python's Flying Circus, embora muitas pessoas façam associação com o réptil do mesmo nome (em português, píton ou pitão).

# %% [markdown]
# ### **Exemplo da página do python no wikipedia, onde podemos ver que as informações respondidas estão corretas**

# %% [markdown]
# ![image.png](attachment:image.png)
